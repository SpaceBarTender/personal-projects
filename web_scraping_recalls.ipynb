# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
import re
import lxml
from urllib.request import urlopen
from IPython.display import display
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### Steps to web-scrape a food recalls website for its recall data.
#
# -Inspect all of the interested web elements of the webpage and note their HTML tags.
# -Initiate an empty list for each web element.
# -While loop over web pages in site based on number rule
#     -Establish beautifulsoup object
#     -Iterate over the nested webparts that are contained within the larger ones and append to initiated lists
# -Turn initiated lists into Pandas Series objects to enable Pandas value counts
# -Test out the value counts
# -Create data dictionary of "Column_Names" : series_objects established in previous step
# -Turn dictionary into pandas dataframe
# -Query data frame to ensure table is adequate

# %%
status_ = []
title_ = []
reason_ = []
date_ = []
summary_ = []
impacted_products_ = []
link_ = []
page = 0
while page!= 25:
    url = f"https://www.fsis.usda.gov/recalls?page={page}"
    response = requests.get(url)
    html = response.content
    soup = bs(html, "lxml")
    view_content = soup.find('div', class_='view__content')
    view_rows = view_content.find_all('div', class_='view__row')
    for row in view_rows:
        status = row.find('div', class_="recall-teaser__status").text.replace('\n',' ')
        if "Active" in status:
            view_status = row.find('span', class_="tag tag--active").text
            status_.append(status)
            teaser_title = row.find('h3', class_='recall-teaser__title').text
            title_.append(teaser_title)
            reason = row.find('a', class_="tag tag--reason").text
            reason_.append(reason)
            date = row.find('div', class_="recall-teaser__date").text.replace('\n','')
            date_.append(date)
            summary = row.find('div', class_="recall-teaser__summary").text.replace('\n','')
            summary_.append(summary_)
            impacted_products = row.find('div', class_="recall-teaser__products").text
            impacted_products_.append(impacted_products)
            link = row.find("a", href=re.compile("^(/recalls-alerts/)((?!:).)*$"))
            link_.append(link)

        # print(f'''
        # Status:{status}
        # Date: {date}
        # Reason: {reason}
        # Title: {teaser_title}
        # Summary: {summary}
        # {ip}
        # Link: https://www.fsis.usda.gov{link.attrs['href']}
        # ''')

    page = page + 1

links=[]
for link in link_:
    item = f"https://www.fsis.usda.gov{link.attrs['href']}"
    links.append(item)



# sub_strings = ['Impacted Products', '\\n', '\\t']

# impacted_products_final = []

# for item in impacted_products_:
#     item = re.sub('|'.join(sub_strings), '', item)
#     impacted_products_final.append(item)

# %%
status_series = pd.Series(status_)
status_series.value_counts()
title_series = pd.Series(title_)
reason_series = pd.Series(reason_)
reason_series.value_counts()
date_series = pd.Series(date_)
date_series.value_counts()
impacted_products_series = pd.Series(impacted_products_final)
link_series = pd.Series(links)

data_dictionary = {"Status" : status_series, "Title" : title_series, "Reason" : reason_series, "Date" : date_series, "Impacted_Products" : impacted_products_series, "Link" : link_}
df = pd.DataFrame(data=data_dictionary)

ds = df.loc[(df['Reason'] == 'Product Contamination') | (df['Reason'] == 'Unfit for Human Consumption') | (df['Reason'] == 'Unfit for Human Consumption')]

def remove_substrings(str_list, substr_list):
    new_list = []
    for item in str_list:
        item = re.sub('|'.join(substr_list), '', item)
        new_list.append(item)
    return new_list

sub_strings = ['Impacted Products', '\\n', '\\t']

df["Impacted_Products"] = remove_substrings(df["Impacted_Products"],sub_strings) 

ds[["Reason", "Title", 'Impacted_Products','Link']]
# Out:
#  Active     93
# Name: count, dtype: int64
# Product Contamination                     33
# Misbranding                               28
# Produced Without Benefit of Inspection    11
# Import Violation                           8
# Unfit for Human Consumption                3
# Processing Defect                          3
# Unreported Allergens                       3
# Insanitary Conditions                      2
# Mislabeling                                2
# Name: count, dtype: int64
#         Sat, 12/18/2021 - Current          2
#         Fri, 02/03/2023 - Current          2
#         Fri, 06/30/2023 - Current          2
#         Fri, 10/29/2021 - Current          1
#         Fri, 03/12/2021 - Current          1
#                                           ..
#         Tue, 01/31/2023 - Current          1
#         Wed, 02/01/2023 - Current          1
#         Wed, 02/08/2023 - Current          1
#         Tue, 02/14/2023 - Current          1
#         Fri, 11/22/2019 - Current          1
# Name: count, Length: 90, dtype: int64
#                          Reason  \
# 2         Product Contamination
# 4         Product Contamination
# 11  Unfit for Human Consumption
# 13        Product Contamination
# 14        Product Contamination
# 21        Product Contamination
# 22        Product Contamination
# 34        Product Contamination
# 35        Product Contamination
# 36        Product Contamination
# 37        Product Contamination
# 39        Product Contamination
# 41        Product Contamination
# 42        Product Contamination
# 46        Product Contamination
# 49        Product Contamination
# 51        Product Contamination
# 54        Product Contamination
# 56        Product Contamination
# 58        Product Contamination
# 60        Product Contamination
# 62        Product Contamination
# 63        Product Contamination
# 65        Product Contamination
# 66        Product Contamination
# 70        Product Contamination
# 78        Product Contamination
# 80        Product Contamination
# 81        Product Contamination
# 82  Unfit for Human Consumption
# 83        Product Contamination
# 84        Product Contamination
# 85        Product Contamination
# 87        Product Contamination
# 90  Unfit for Human Consumption
# 92        Product Contamination
#
#                                                 Title  \
# 2   FSIS Issues Public Health Alert for Fresh Sala...
# 4   FSIS Issues Public Health Alert for Raw Beef P...
# 11  House of Raeford Recalls Foster Farms Brand Mi...
# 13  Conagra Brands, Inc., Recalls Frozen Beef Shep...
# 14  Johnsonville, LLC, Recalls Beddar With Cheddar...
# 21  FSIS Issues Public Health Alert for Fresh Sala...
# 22  Hoyo, SBC Recalls Frozen, Ready-To-Eat Beef Sa...
# 34  FSIS Issues Public Health Alert for Ground Bee...
# 35  FSIS Issues Public Health Alert for Fully Cook...
# 36   FSIS Issues Public Health Alert for Ground Be...
# 37  FSIS Issues Public Health Alert for Ready-To-E...
# 39  FSIS Issues Public Health Alert For Specific G...
# 41  FSIS Issues Public Health Alert for Perdue Fro...
# 42  FSIS Issues Public Health Alert for Ground Bee...
# 46   FSIS Issues Public Health Alert for Ready-to-...
# 49  FSIS Issues Public Health Alert for Raw Ground...
# 51  FSIS Issues Public Health Alert for Ground Bee...
# 54  FSIS Issues Public Health Alert for Chicken Sa...
# 56  FSIS Issues Public Health Alert for Ready-To-E...
# 58  FSIS Issues Public Health Alert for Summer Sau...
# 60   FSIS Issues Public Health Alert for Salame St...
# 62  FSIS Issues Public Health Alert for Frozen Raw...
# 63  FSIS Issues Public Health Alert for Frozen, Co...
# 65  FSIS Issues Public Health Alert for Raw Ground...
# 66  FSIS Issues Public Health Alert for Raw Ground...
# 70  FSIS Issues Public Health Alert for Raw Ground...
# 78  FSIS Issues Public Health Alert for Chicken an...
# 80  FSIS Issues Public Health Alert for Spaghetti ...
# 81  FSIS Issues Public Health Alert for Ready-To-E...
# 82  FSIS Issues Public Health Alert for Ineligible...
# 83  FSIS Issues Public Health Alert for Ready to E...
# 84  FSIS Issues Public Health Alert for Ready-to-E...
# 85  FSIS Issues Public Health Alert for Meat and P...
# 87  FSIS Issues Public Health Alert for Raw Beef R...
# 90  FSIS Issues Public Health Alert for Products A...
# 92  FSIS Issues Public Health Alert for Products P...
#
#                                     Impacted_Products  \
# 2   •8.65-oz. plastic film packages containing “Ch...
# 4   •Approximately 1.5-lb. plastic tray packages c...
# 11  •1.83-lb. resealable bag containing “FOSTER FA...
# 13  4.31 lbs. cases of “MC Beef Shepherd’s Pie” wi...
# 14  •14-oz. vacuum-packed packages of “Johnsonvill...
# 21  •5.5-oz. clear plastic packages containing “Fr...
# 22  Bulk boxes containing 75 pieces of “HOYO Beef ...
# 34  •Varying weights of ground beef packed in butc...
# 35  •1-lb. chubs containing “JET HIGH PRAIRIE MEAT...
# 36  •1-lb. plastic vacuum-packed packages containi...
# 37  15-oz. vacuum-packed packages containing “Our ...
# 39  •10-oz. plastic vacuum-packed packages contain...
# 41  42 oz. plastic bags containing “PERDUE CHICKEN...
# 42  1-lb. vacuum sealed packages containing "Groun...
# 46  •14.5-oz. plastic clamshell containers labeled...
# 49   •16-oz. vacuum-sealed packages containing “OR...
# 51  •1-lb. foam trays containing “ALL NATURAL LAUR...
# 54  •12-oz. plastic tray packages containing “Trad...
# 56  8-oz and 16-oz. deli hinged containers of “sim...
# 58  8-oz. chub containing RTE Swiss Meat & Sausage...
# 60  •2-oz packages containing Citterio “Premium It...
# 62
# 63  4-lb. plastic bags containing “FULLY COOKED CH...
# 65  1-lb. packages of Nature’s Promise Free from 9...
# 66  •1-lb. packages containing “Lonely Lane Farms ...
# 70  2-lb (approximately) trays containing raw grou...
# 78       Frozen Ready to eat chicken and pork tamale
# 80  Take home meals spaghetti and meatballs in mar...
# 81  Ready to eat spaghetti squash with alrfedo chi...
# 82
# 83
# 84
# 85
# 87          P&S Ravioli Company 12 Jumbo Meat Ravioli
# 90
# 92
#
#                                                  Link
# 2   [FSIS Issues Public Health Alert for Fresh Sal...
# 4   [FSIS Issues Public Health Alert for Raw Beef ...
# 11  [House of Raeford Recalls Foster Farms Brand M...
# 13  [Conagra Brands, Inc., Recalls Frozen Beef She...
# 14  [Johnsonville, LLC, Recalls Beddar With Chedda...
# 21  [FSIS Issues Public Health Alert for Fresh Sal...
# 22  [Hoyo, SBC Recalls Frozen, Ready-To-Eat Beef S...
# 34  [FSIS Issues Public Health Alert for Ground Be...
# 35  [FSIS Issues Public Health Alert for Fully Coo...
# 36  [ FSIS Issues Public Health Alert for Ground B...
# 37  [FSIS Issues Public Health Alert for Ready-To-...
# 39  [FSIS Issues Public Health Alert For Specific ...
# 41  [FSIS Issues Public Health Alert for Perdue Fr...
# 42  [FSIS Issues Public Health Alert for Ground Be...
# 46  [ FSIS Issues Public Health Alert for Ready-to...
# 49  [FSIS Issues Public Health Alert for Raw Groun...
# 51  [FSIS Issues Public Health Alert for Ground Be...
# 54  [FSIS Issues Public Health Alert for Chicken S...
# 56  [FSIS Issues Public Health Alert for Ready-To-...
# 58  [FSIS Issues Public Health Alert for Summer Sa...
# 60  [ FSIS Issues Public Health Alert for Salame S...
# 62  [FSIS Issues Public Health Alert for Frozen Ra...
# 63  [FSIS Issues Public Health Alert for Frozen, C...
# 65  [FSIS Issues Public Health Alert for Raw Groun...
# 66  [FSIS Issues Public Health Alert for Raw Groun...
# 70  [FSIS Issues Public Health Alert for Raw Groun...
# 78  [FSIS Issues Public Health Alert for Chicken a...
# 80  [FSIS Issues Public Health Alert for Spaghetti...
# 81  [FSIS Issues Public Health Alert for Ready-To-...
# 82  [FSIS Issues Public Health Alert for Ineligibl...
# 83  [FSIS Issues Public Health Alert for Ready to ...
# 84  [FSIS Issues Public Health Alert for Ready-to-...
# 85  [FSIS Issues Public Health Alert for Meat and ...
# 87  [FSIS Issues Public Health Alert for Raw Beef ...
# 90  [FSIS Issues Public Health Alert for Products ...
# 92  [FSIS Issues Public Health Alert for Products ...

# %%
from collections import Counter
import collections
import itertools
def word_count_dict_from_text_col(column_or_strlist):
    words = []
    for item in column_or_strlist:
        item = item.lower().split()
        words.append(item)           
    words = list(itertools.chain.from_iterable(words))
    counts = collections.Counter(x for x in words if x)
    return counts
w = word_count_dict_from_text_col(df["Reason"])
w
word_count_df = pd.DataFrame(data=w, index=[0])
# Out:
# Counter({'product': 33,
#          'contamination': 33,
#          'misbranding': 28,
#          'produced': 11,
#          'without': 11,
#          'benefit': 11,
#          'of': 11,
#          'inspection': 11,
#          'import': 8,
#          'violation': 8,
#          'unfit': 3,
#          'for': 3,
#          'human': 3,
#          'consumption': 3,
#          'processing': 3,
#          'defect': 3,
#          'unreported': 3,
#          'allergens': 3,
#          'insanitary': 2,
#          'conditions': 2,
#          'mislabeling': 2})
